# %%
import pandas as pd
marks = pd.Series([80, 90, 70, 60, 50])
print(marks)

### dataframe
student =  {
    "name": ["sobia","aqsa", "fiza", "mehak"],
    "age":[20, 19, 15 ,22],
    "marks":[100, 90, 80, 50]
}
## dataframe
df = pd.DataFrame(student)
print(df)
print(df.head())
df.info()
print(df.describe())
# Out:
# 0    80
# 1    90
# 2    70
# 3    60
# 4    50
# dtype: int64
#     name  age  marks
# 0  sobia   20    100
# 1   aqsa   19     90
# 2   fiza   15     80
# 3  mehak   22     50
#     name  age  marks
# 0  sobia   20    100
# 1   aqsa   19     90
# 2   fiza   15     80
# 3  mehak   22     50
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      str
#  1   age     4 non-null      int64
#  2   marks   4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
#             age       marks
# count   4.00000    4.000000
# mean   19.00000   80.000000
# std     2.94392   21.602469
# min    15.00000   50.000000
# 25%    18.00000   72.500000
# 50%    19.50000   85.000000
# 75%    20.50000   92.500000
# max    22.00000  100.000000
