# %%
name = "fiza"
age = 20
print(name)
print(age)

## data types
a = 10
b = 5.5
c = "python"
d = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))

### operators

x = 10
y = 15
print(x+y)
print(x*y)
print(x-y)
print(x/y)

### if else
num = 10
if num >7:
    print("number is greater than 7")
else:
    print("number  is 7 or less")
# Out:
# fiza
# 20
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 25
# 150
# -5
# 0.6666666666666666
# number is greater than 7

# %%
### loop
for i in range(1,6):
    print(i)

#### function
def greet(name):
    print("hello", name)
greet("fiza")
# Out:
# 1
# 2
# 3
# 4
# 5
# hello fiza
