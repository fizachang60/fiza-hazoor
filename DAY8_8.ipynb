# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create Data
data = {
    "product": ["Laptop", "Phone", "Mouse", "Charger", "Tablet"],
    "Sales": [900, 700, 400, 120, 456]
}

# Create DataFrame
df = pd.DataFrame(data)

# Show DataFrame
print(df)

# Bar Chart
plt.figure(figsize=(7,5))
plt.bar(df["product"], df["Sales"])
plt.title("Product Sales")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# Line Chart
plt.figure(figsize=(7,5))
plt.plot(df["product"], df["Sales"], marker="o")
plt.title("Sales Trend")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()

# Pie Chart
plt.figure(figsize=(6,6))
plt.pie(df["Sales"], labels=df["product"], autopct="%1.1f%%")
plt.title("Sales Distribution")
plt.show()
# Out:
#    product  Sales
# 0   Laptop    900
# 1    Phone    700
# 2    Mouse    400
# 3  Charger    120
# 4   Tablet    456
