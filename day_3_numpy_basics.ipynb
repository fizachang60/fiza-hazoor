# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40, 50])
print(arr)
# Out:
# [10 20 30 40 50]

# %%
## array indexing
print(arr[0])
print(arr[3])
print(arr[4])
# Out:
# 10
# 40
# 50

# %%
## addation
print(arr + 5)
# Out:
# [15 25 35 45 55]

# %%
### multiplication
print(arr*4)
# Out:
# [ 40  80 120 160 200]
