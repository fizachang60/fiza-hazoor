# %%
####  numpy import
import numpy as np

### array create
arr = np.array([10, 20, 30, 40, 50])
print(arr)

## ARRAY INFORMATION
print("shape:", arr.shape)
print("data type:", arr.dtype)
print("dimension:", arr.ndim)

##3 MATHEMATICAL OPERATION
print("addation:", arr+7)
print("multiplication:", arr*9)

##### MEAN AND SUM
print("sum:", np.sum(arr))
print("mean:", np.mean(arr))
print("maximum:", np.max(arr))
print("minimum:", np.min(arr))
# Out:
# [10 20 30 40 50]
# shape: (5,)
# data type: int64
# dimension: 1
# addation: [17 27 37 47 57]
# multiplication: [ 90 180 270 360 450]
# sum: 150
# mean: 30.0
# maximum: 50
# minimum: 10
