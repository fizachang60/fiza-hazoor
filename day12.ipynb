# %%
import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())
import pandas as pd

df = pd.read_csv(r"C:\Users\DELL\Documents\data.csv")
print(df.head())



import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("data.csv")

# Display first 5 rows
print(df.head())

# Dataset information
print(df.info())

# Summary statistics
print(df.describe())

# Data cleaning
df = df.dropna()

# Save cleaned dataset
df.to_csv("cleaned_data.csv", index=False)

# Create chart
df["Marks"].plot(kind="bar")
plt.title("Marks Chart")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# Business Insights
print("1. Dataset loaded successfully.")
print("2. Missing values removed.")
print("3. Cleaned dataset saved.")
print("4. Chart created successfully.")
print("5. Notebook formatting improved.")

print("Day 12 Project Improvement Completed Successfully!")
# Out:
#      Name  Age  Marks
# 0     Ali   20     85
# 1    Sara   21     90
# 2   Ahmed   19     78
# 3  Ayesha   22     88
#      Name  Age  Marks
# 0     Ali   20     85
# 1    Sara   21     90
# 2   Ahmed   19     78
# 3  Ayesha   22     88
#      Name  Age  Marks
# 0     Ali   20     85
# 1    Sara   21     90
# 2   Ahmed   19     78
# 3  Ayesha   22     88
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   Age     4 non-null      int64
#  2   Marks   4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes
# None
#              Age      Marks
# count   4.000000   4.000000
# mean   20.500000  85.250000
# std     1.290994   5.251984
# min    19.000000  78.000000
# 25%    19.750000  83.250000
# 50%    20.500000  86.500000
# 75%    21.250000  88.500000
# max    22.000000  90.000000
# ...
